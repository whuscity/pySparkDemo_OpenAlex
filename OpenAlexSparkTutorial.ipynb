# %% [markdown]
# # 初始化

# %%
# 初始化，请填写appname参数，其中包含你的用户名和本次使用数据集
# %run spark_openalex_init.py --appname=MarioZZJ_OpenAlex
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.17.60.211:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://c8mao:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>MarioZZJ_OpenAlex</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# 可以在新标签页访问上面的 Spark UI 链接，查看任务执行进度，也可以去 Spark UI 总页面，查看多个 app 的并行运行情况。

# %% [markdown]
# # 查看 schema
#
# 此时我们获取了 27 个 `pyspark.sql.dataframe.DataFrame` 对象，分别对应 27 张表，可以使用 `showSchema()` 方法查看字段。
#
# 27 个对象的变量名：`Authors`, `AuthorsIds`, `AuthorsCountsByYear`, `Concepts`, `ConceptsAncestors`, `ConceptsCountsByYear`, `ConceptsIds`, `ConceptsRelatedConcepts`, `Institutions`, `InstitutionsAssociatedInstitutions`, `InstitutionsCountsByYear`, `InstitutionsGeo`, `InstitutionsIds`, `Works`, `WorksAuthorships`, `WorksAlternateHostVenues`, `WorksBiblio`, `WorksConcepts`, `WorksHostVenues`, `WorksIds`, `WorksMesh`, `WorksOpenAccess`, `WorksRelatedWorks`, `WorksReferencedWorks`, `Venues`, `VenuesCountsByYear`, `VenuesIds`。
#
# 各表详细的 Schema 可以查看 [OpenAlex 文档](https://docs.openalex.org/download-snapshot/upload-to-your-database/load-to-a-relational-database/postgres-schema-diagram)。
# ![schema](https://2520693015-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2FSj6S26Opvy3KVj3QQGMc%2Fuploads%2FS3eqe0lsHYmqxJTcPa9V%2Fopenalex-schema.png?alt=media&token=64f070a8-ca96-4639-96d7-06d8a6ea659d)

# %%
Authors.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- orcid: string (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- display_name_alternatives: string (nullable = true)
#  |-- works_count: integer (nullable = true)
#  |-- cited_by_count: integer (nullable = true)
#  |-- last_known_institution: string (nullable = true)
#  |-- works_api_url: string (nullable = true)
#  |-- updated_date: date (nullable = true)
#  |-- display_name_alternatives_array: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
Works
# Out:
# DataFrame[id: string, doi: string, title: string, display_name: string, publication_year: int, publication_date: string, type: string, cited_by_count: int, is_retracted: boolean, is_paratext: boolean, host_venue: string]

# %% [markdown]
# # 案例：模糊检索
# 类似于 SQL 中的 `WHERE` `LIKE`

# %%
# 查找前 10 篇标题包含'covid'的论文
works = Works.filter(
            Works.display_name.like('%covid%') # filter() 过滤中填入表达式，可以用`==`精确匹配，也可用 like() 模糊匹配
        ).limit(10).toPandas() # 建议探索时多用 limit，减少对资源的占用 
                    # toPandas() 转化为 dataframe，直接在 notebook 展示
works
# Out:
#                                  id  \
# 0  https://openalex.org/W4213007532
# 1  https://openalex.org/W4225105503
# 2  https://openalex.org/W4225259912
# 3  https://openalex.org/W4225852779
# 4  https://openalex.org/W4206974766
# 5  https://openalex.org/W4200272339
# 6  https://openalex.org/W4226093403
# 7  https://openalex.org/W4210273141
# 8  https://openalex.org/W4210584131
# 9  https://openalex.org/W3213651567
#
#                                              doi  \
# 0        https://doi.org/10.15446/ts.v24n1.94179
# 1               https://doi.org/10.1136/bmj.o867
# 2              https://doi.org/10.1136/bmj.o1096
# 3  https://doi.org/10.29327/icidsuim20221.461057
# 4        https://doi.org/10.14393/ufu.di.2022.24
# 5  https://doi.org/10.1080/13527266.2021.2012499
# 6  https://doi.org/10.1080/0142159x.2022.2027902
# 7     https://doi.org/10.7476/9786557081587.0027
# 8    https://doi.org/10.1016/j.shaw.2021.12.1275
# 9          https://doi.org/10.48102/pi.v29i3.414
#
#                                                title  \
# 0  Concepciones de salud, Sistema de salud públic...
# 1  The benefits of large scale covid-19 vaccination.
# 2  The government wants us to learn to live with ...
# 3  Saberes e práticas: primeiro ano de uma residê...
# 4  A atuação da UFU frente a pandemia de covid-19...
# 5  Advertising content and online engagement on s...
# 6  The need to preserve the humanistic nature of ...
# 7  A experiência do Proqualis na produção e divul...
# 8  Which jobs are lucky against the “biologic” an...
# 9  Psicología basada en la evidencia en tiempos d...
#
#                                         display_name  publication_year  \
# 0  Concepciones de salud, Sistema de salud públic...              2022
# 1  The benefits of large scale covid-19 vaccination.              2022
# 2  The government wants us to learn to live with ...              2022
# 3  Saberes e práticas: primeiro ano de uma residê...              2022
# 4  A atuação da UFU frente a pandemia de covid-19...              2022
# 5  Advertising content and online engagement on s...              2021
# 6  The need to preserve the humanistic nature of ...              2022
# 7  A experiência do Proqualis na produção e divul...              2022
# 8  Which jobs are lucky against the “biologic” an...              2022
# 9  Psicología basada en la evidencia en tiempos d...              2021
#
#   publication_date             type  cited_by_count  is_retracted is_paratext  \
# 0       2022-01-03  journal-article               0         False        None
# 1       2022-04-27  journal-article               0         False        None
# 2       2022-04-29  journal-article               0         False        None
# 3       2022-01-01     book-chapter               0         False       False
# 4       2022-01-24     dissertation               0         False       False
# 5       2021-12-26  journal-article               0         False       False
# 6       2022-01-20  journal-article               0         False       False
# 7       2022-01-26     book-chapter               0         False       False
# 8       2022-01-01  journal-article               0         False       False
# 9       2021-11-09  journal-article               0         False       False
#
#                                           host_venue
# 0  https://api.openalex.org/works?filter=cites:W4...
# 1  https://api.openalex.org/works?filter=cites:W4...
# 2  https://api.openalex.org/works?filter=cites:W4...
# 3  https://api.openalex.org/works?filter=cites:W4...
# 4  https://api.openalex.org/works?filter=cites:W4...
# 5  https://api.openalex.org/works?filter=cites:W4...
# 6  https://api.openalex.org/works?filter=cites:W4...
# 7  https://api.openalex.org/works?filter=cites:W4...
# 8  https://api.openalex.org/works?filter=cites:W4...
# 9  https://api.openalex.org/works?filter=cites:W3...

# %%
WorksReferencedWorks
# Out:
# DataFrame[work_id: string, referenced_work_id: string]

# %% [markdown]
# # 案例：表连接
# 类似于 SQL 中的 `JOIN`

# %%
# 查找文献x的前10篇引文
selected_citations = Works.filter(Works.id=='https://openalex.org/W3213651567').join(
    WorksReferencedWorks, # 第一个参数：连接的表
    Works.id == WorksReferencedWorks.work_id, # 第二个参数：连接依据，where
    how = 'inner') # 第三个参数：连接方式，这里为 inner join
selected_citations.limit(10).toPandas() # 如果没有调用 toPandas()、show()等，变量仅保留计算图，并未实际开始计算
# Out:
#                                  id                                    doi  \
# 0  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
# 1  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
# 2  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
# 3  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
# 4  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
# 5  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
# 6  https://openalex.org/W3213651567  https://doi.org/10.48102/pi.v29i3.414
#
#                                                title  \
# 0  Psicología basada en la evidencia en tiempos d...
# 1  Psicología basada en la evidencia en tiempos d...
# 2  Psicología basada en la evidencia en tiempos d...
# 3  Psicología basada en la evidencia en tiempos d...
# 4  Psicología basada en la evidencia en tiempos d...
# 5  Psicología basada en la evidencia en tiempos d...
# 6  Psicología basada en la evidencia en tiempos d...
#
#                                         display_name  publication_year  \
# 0  Psicología basada en la evidencia en tiempos d...              2021
# 1  Psicología basada en la evidencia en tiempos d...              2021
# 2  Psicología basada en la evidencia en tiempos d...              2021
# 3  Psicología basada en la evidencia en tiempos d...              2021
# 4  Psicología basada en la evidencia en tiempos d...              2021
# 5  Psicología basada en la evidencia en tiempos d...              2021
# 6  Psicología basada en la evidencia en tiempos d...              2021
#
#   publication_date             type  cited_by_count  is_retracted  \
# 0       2021-11-09  journal-article               0         False
# 1       2021-11-09  journal-article               0         False
# 2       2021-11-09  journal-article               0         False
# 3       2021-11-09  journal-article               0         False
# 4       2021-11-09  journal-article               0         False
# 5       2021-11-09  journal-article               0         False
# 6       2021-11-09  journal-article               0         False
#
#    is_paratext                                         host_venue  \
# 0        False  https://api.openalex.org/works?filter=cites:W3...
# 1        False  https://api.openalex.org/works?filter=cites:W3...
# 2        False  https://api.openalex.org/works?filter=cites:W3...
# 3        False  https://api.openalex.org/works?filter=cites:W3...
# 4        False  https://api.openalex.org/works?filter=cites:W3...
# 5        False  https://api.openalex.org/works?filter=cites:W3...
# 6        False  https://api.openalex.org/works?filter=cites:W3...
#
#                             work_id                referenced_work_id
# 0  https://openalex.org/W3213651567  https://openalex.org/W1493925022
# 1  https://openalex.org/W3213651567  https://openalex.org/W1765504387
# 2  https://openalex.org/W3213651567  https://openalex.org/W3039521750
# 3  https://openalex.org/W3213651567  https://openalex.org/W3081416251
# 4  https://openalex.org/W3213651567  https://openalex.org/W3094350895
# 5  https://openalex.org/W3213651567  https://openalex.org/W3132890237
# 6  https://openalex.org/W3213651567  https://openalex.org/W3172256592

# %% [markdown]
# # 案例：聚合统计
# 类似于 SQL 中的 `GROUP BY`

# %%
# 统计文献x的引文
selected_meshes = WorksMesh.filter(WorksMesh.work_id == 'https://openalex.org/W2513796179')\
                    .groupBy(WorksMesh.work_id).agg(# agg() 聚合函数
                    F.countDistinct(WorksMesh.descriptor_ui)# countDistinct为去重计数，更多函数可查看 pyspark.sql.functions 的手册
                    .alias("Mesh_D_Count"))# alias 为新生成的列指定别名

selected_meshes.toPandas()
# Out:
#                             work_id  Mesh_D_Count
# 0  https://openalex.org/W2513796179             7

# %% [markdown]
# # 案例：列裁剪
# 类似于 SQL 中的 `SELECT`。对于研究需要，大多数表我们只需要部分字段。尽早进行列裁剪对于减少计算压力具有一定帮助。

# %%
# 取出 Works 表的前 10 条数据，只需要 id 和 doi 两个字段
works_sub = Works.select(
                Works.id,
                Works.doi
)
works_sub.limit(10).toPandas()
# Out:
#                                  id  \
# 0  https://openalex.org/W2973187907
# 1  https://openalex.org/W2513002348
# 2  https://openalex.org/W2946982473
# 3  https://openalex.org/W2960429651
# 4  https://openalex.org/W3022436951
# 5  https://openalex.org/W3022449202
# 6  https://openalex.org/W3022723715
# 7  https://openalex.org/W2982244448
# 8  https://openalex.org/W3022891036
# 9  https://openalex.org/W3022072931
#
#                                               doi
# 0      https://doi.org/10.31080/asor.2019.02.0071
# 1      https://doi.org/10.1016/j.bbmt.2015.11.882
# 2   https://doi.org/10.1016/s1569-1993(19)30280-2
# 3  https://doi.org/10.1088/1755-1315/252/5/052020
# 4                                            None
# 5    https://doi.org/10.1016/0020-7292(94)90341-7
# 6         https://doi.org/10.7554/elife.50232.sa1
# 7   https://doi.org/10.1093/eurheartj/ehz745.0735
# 8             https://doi.org/10.35826/ijetsar.37
# 9                 https://doi.org/10.1111/an.1239

# %% [markdown]
# # 案例：保存数据
# 有时我们需要将中间结果进行保存，如果数据量较小，可以对 toPandas() 的 dataframe 对象直接使用 pandas 库的方法保存，而当数据量较大时，建议使用 spark 的 `write()` 方法保存为多个文件，减小内存和运算压力。

# %%
# 取出 Works 表的前 1000 条数据，只需要 id 和 doi 两个字段，保存至指定文件夹
works_sub.limit(1000).write.csv("./data/id_doi",header=True,mode="overwrite") # header 为 True 时，每个子文件均包含表头（建议，方便后续读取）

# %% [markdown]
# 此时在 `./data/id_doi` 文件夹下就会存储若干个文件，保存所有取出数据

# %% [markdown]
# # 案例：读取数据
# 对于上述保存的分片数据，同样可以使用 spark 的 `read()` 方法将其读取为 `pyspark.sql.dataframe.DataFrame` 对象，进行后续操作。

# %%
works_sub = spark.read.csv("./data/id_doi", header=True, inferSchema=True)
print(type(works_sub))
works_sub.limit(10).toPandas()
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
#                                  id  \
# 0  https://openalex.org/W2105305796
# 1  https://openalex.org/W2065086217
# 2  https://openalex.org/W2065099785
# 3  https://openalex.org/W2065112245
# 4  https://openalex.org/W2065115307
# 5  https://openalex.org/W2065158039
# 6  https://openalex.org/W2065347846
# 7  https://openalex.org/W2271568448
# 8  https://openalex.org/W2973075386
# 9  https://openalex.org/W3213985658
#
#                                                  doi
# 0  https://doi.org/10.1097/01.ju.0000118480.04204.35
# 1               https://doi.org/10.5261/2014.gen4.08
# 2   https://doi.org/10.1111/j.1525-1438.2007.00785.x
# 3  https://doi.org/10.1016/j.transproceed.2014.08...
# 4              https://doi.org/10.1055/s-2005-870897
# 5        https://doi.org/10.1016/j.jopan.2006.03.001
# 6                    https://doi.org/10.1038/433367a
# 7                  https://doi.org/10.1111/trf.13514
# 8                 https://doi.org/10.1117/12.2532096
# 9               https://doi.org/10.2139/ssrn.3170307

# %% [markdown]
# 更多使用方法，可以参考 [PySpark 手册](https://spark.apache.org/docs/3.1.2/api/python/getting_started/index.html)

# %% [markdown]
# # 重要：释放 session
#
# 请在使用资源时保持良好习惯，结束使用时执行下列语句对占用资源进行释放；或 shutdown notebook 也可对资源进行释放。

# %%
spark.sparkContext.stop()
spark.stop()
